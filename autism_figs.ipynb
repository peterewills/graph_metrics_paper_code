# %% [markdown]
# # Plotting ABIDE Autism Data

# %%
kwargs = {
    'sym' : '',
    'whis' : [5,95]
}

figures_dir = '/Users/peterwills/google-drive/Research/Graph Distance Study/metrics_paper/figures'

labels = ['Edit', 'Resistance', 'DeltaCon', 'NetSimile', 'Lambda (A)',
          'Lambda (L)', 'Lambda (NL)']

# %% [markdown]
# ### Threshold 0.5, Binary

# %%
data_dict = pd.read_pickle('pickled_data/abide_t_0.5_binary.p')

adj_null = data_dict['results_df_null']['Correlation Distances'].T
adj_not = data_dict['results_df_not_null']['Correlation Distances'].T

for item in [adj_null,adj_not]:
    item.index = range(item.shape[0])

adj_scaled = (adj_not - adj_null.mean())/adj_null.std()

abide_labels = labels + ['Lambda (A) k=5','Lambda (L) k=5','Lambda (NL) k=5']
adj_scaled.columns = abide_labels

plt.figure(figsize=(6,4))
adj_scaled.iloc[:,:-3].boxplot(**kwargs);
plt.ylabel('Scaled Distance $\widehat{D}_2$');
plt.xticks(rotation=90);
plt.title('ABIDE Autism with $T=1/2$ (Binary)');

fig = plt.gcf();
fig.savefig(os.path.join(figures_dir,'abide_binary_t05.pdf'),dpi=300,bbox_inches='tight');

# %%
adj_null['Edit'].unique()
# Out:
# array([ 829.,    0.])

# %%
data_dict = pd.read_pickle('pickled_data/abide_t_0.5.p')

adj_null = data_dict['results_df_null']['Correlation Distances'].T
adj_not = data_dict['results_df_not_null']['Correlation Distances'].T

for item in [adj_null,adj_not]:
    item.index = range(item.shape[0])

adj_scaled = (adj_not - adj_null.mean())/adj_null.std()

abide_labels = labels + ['Lambda (A) k=5','Lambda (L) k=5','Lambda (NL) k=5']
adj_scaled.columns = abide_labels

plt.figure(figsize=(6,4))
adj_scaled.iloc[:,:-3].boxplot(**kwargs);
plt.ylabel('Scaled Distance $\widehat{D}_2$');
plt.xticks(rotation=90);
plt.title('ABIDE Autism with $T=1/2$ (Weighted)');

fig = plt.gcf();
fig.savefig(os.path.join(figures_dir,'abide_weighted_t05.pdf'),dpi=300,bbox_inches='tight');

# %%
data_dict = pd.read_pickle('pickled_data/abide_t_0.p')

adj_null = data_dict['results_df_null']['Correlation Distances'].T
adj_not = data_dict['results_df_not_null']['Correlation Distances'].T

for item in [adj_null,adj_not]:
    item.index = range(item.shape[0])

adj_scaled = (adj_not - adj_null.mean())/adj_null.std()

abide_labels = labels + ['Lambda (A) k=5','Lambda (L) k=5','Lambda (NL) k=5']
adj_scaled.columns = abide_labels

plt.figure(figsize=(6,4))
adj_scaled.iloc[:,:-3].boxplot(**kwargs);
plt.ylabel('Scaled Distance $\widehat{D}_2$');
plt.xticks(rotation=90);
plt.title('ABIDE Autism with $T=0$ (Weighted)');

fig = plt.gcf();
fig.savefig(os.path.join(figures_dir,'abide_weighted_t0.pdf'),dpi=300,bbox_inches='tight');

# %% [markdown]
# What's up with NetSimile? We need to explain this.

# %%
adj_null['NetSimile'].unique()
# Out:
# array([  8.        ,  18.        ,  23.11349184])

# %%
adj_not['NetSimile'].unique()
# Out:
# array([ 23.11349184,  18.        ,  15.18598868,  11.54508388,
#         23.46557323,  11.54508388,  17.01787479,  23.58675447,
#         10.1871878 ,  23.34629057,   8.        ,  23.05650276,  23.17096641])

# %% [markdown]
# # Binary, Threshold 0.8

# %%
data_dict = pd.read_pickle('pickled_data/abide_t_0.8_binary.p')

adj_null = data_dict['results_df_null']['Correlation Distances'].T
adj_not = data_dict['results_df_not_null']['Correlation Distances'].T

for item in [adj_null,adj_not]:
    item.index = range(item.shape[0])

adj_scaled = (adj_not - adj_null.mean())/adj_null.std()

abide_labels = labels + ['Lambda (A) k=5','Lambda (L) k=5','Lambda (NL) k=5']
adj_scaled.columns = abide_labels

plt.figure(figsize=(6,4))
adj_scaled.iloc[:,:-3].boxplot(**kwargs);
plt.ylabel('Scaled Distance $\widehat{D}_2$');
plt.xticks(rotation=90);
plt.title('ABIDE Autism with $T=0.8$ (Binary)');

fig = plt.gcf();
fig.savefig(os.path.join(figures_dir,'abide_binary_t08.pdf'),dpi=300,bbox_inches='tight');
